# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np
path = r'C:\Users\tlhqu\Documents\GitHub\Data-visualization\Data\obama.csv'
df = pd.read_csv(path,parse_dates = ['year_month'])
df
# Out:
#      year_month  survey_organization  approve_percent  disapprove_percent
# 0    2009-01-01             ABC/Post             80.0                15.0
# 1    2009-01-01               AP-GFK             74.0                15.0
# 2    2009-01-01                  CNN             84.0                14.0
# 3    2009-01-01  Democracy Corps (D)             51.0                20.0
# 4    2009-01-01       Diageo/Hotline             64.0                 6.5
# ...         ...                  ...              ...                 ...
# 1525 2017-01-01           Quinnipiac             55.0                39.0
# 1526 2017-01-01            Rasmussen             60.0                39.0
# 1527 2017-01-01         SurveyMonkey             62.0                37.5
# 1528 2017-01-01     YouGov/Economist             47.0                42.0
# 1529 2017-01-01                Zogby             50.0                48.0
#
# [1530 rows x 4 columns]

# %%
plt.plot(df.year_month, df.approve_percent,'o',markersize = 2, alpha= 0.3)
plt.show()

# %%
df_mean = df.groupby('year_month').mean()
df_median = df.groupby('year_month').median()

# %%
plt.plot(df_mean.index, df_mean.approve_percent,'red')
plt.plot(df_median.index, df_mean.approve_percent,'green')
plt.legend(['Mean','Median'])
plt.plot(df.year_month, df.approve_percent,'o',markersize = 2, alpha= 0.3)
plt.show()

# %%
df_25 = df.groupby('year_month').quantile(0.25)
df_75 = df.groupby('year_month').quantile(0.75)
plt.plot(df_25.index, df_25.approve_percent,'green')
plt.plot(df_median.index, df_mean.approve_percent,'red')
plt.plot(df_75.index, df_75.approve_percent,'blue')
plt.plot(df.year_month, df.approve_percent,'o',markersize = 2, alpha= 0.3)
plt.legend(['25th Percentile','Median','75th Percentile'])
plt.show()

# %%
'''
Sampling 
'''
# Out:
# '\nSampling \n'

# %%
path = r'C:\Users\tlhqu\Documents\GitHub\Data-visualization\Data\obama_too_big.csv'
df_big = pd.read_csv(path,parse_dates = ['year_month'])
df_big.head()
# Out:
#   year_month survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01      Generated Data             67.0                31.0
# 1 2009-01-01      Harris (Phone)             60.0                29.0
# 2 2009-01-01      Generated Data             65.9                19.1
# 3 2009-01-01      Generated Data             64.6                18.4
# 4 2009-01-01      Generated Data             83.3                11.7

# %%
df.head()
# Out:
#   year_month  survey_organization  approve_percent  disapprove_percent
# 0 2009-01-01             ABC/Post             80.0                15.0
# 1 2009-01-01               AP-GFK             74.0                15.0
# 2 2009-01-01                  CNN             84.0                14.0
# 3 2009-01-01  Democracy Corps (D)             51.0                20.0
# 4 2009-01-01       Diageo/Hotline             64.0                 6.5

# %%
df.shape
# Out:
# (1530, 4)

# %%
df_big.shape
# Out:
# (65499, 4)

# %%
plt.plot(df_big.year_month, df_big.approve_percent,'o',markersize = 2, alpha= 0.3)
plt.show()

# %%
sampled = df_big.sample(frac=0.1)
# use n = 10000 to specify a number samples instead
plt.plot(sampled.year_month, sampled.approve_percent,'o',markersize = 2, alpha= 0.3)
plt.show()
